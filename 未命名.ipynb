# %%
from helpers import *
ft3 = load_pkl('/Users/zmin/PycharmProjects/DisentangleCNN/hook_feat.pkl')
ft3
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-a7ff19e2c011> in <module>
#       1 from helpers import *
# ----> 2 ft3 = load_pkl('/Users/zmin/PycharmProjects/DisentangleCNN/hook_feat.pkl')
#       3 ft3
#
# ~/PycharmProjects/DisentangleCNN/helpers.py in load_pkl(ph)
#      13 def load_pkl(ph):
#      14     with open(ph, 'rb') as f:
# ---> 15         pkl = pickle.load(f)
#      16     return pkl
#      17
#
# /Applications/ML/anaconda3/lib/python3.7/site-packages/torch/storage.py in _load_from_bytes(b)
#     132
#     133 def _load_from_bytes(b):
# --> 134     return torch.load(io.BytesIO(b))
#     135
#     136
#
# /Applications/ML/anaconda3/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     527             with _open_zipfile_reader(f) as opened_zipfile:
# ...
